# %%
NoID=52324966
print(NoID)
nombre1="Diana"
print(nombre1)
nombre2="Maria"
print(nombre2)
apellido=("Valencia")
apellido2=("Escobar")
print(apellido+" "+apellido2)
telefono=3017982806
print(telefono)
edad=int(input("¿Qué edad tiene?"))
estadocivil= "Divorciada"
print(estadocivil)
hijos=2
print(hijos)
estatura=("170cm")
print(estatura)
fechacontrata=input("Digite fecha contratación:")
sueldobasico = float(input("¿Cuánto es el sueldo básico? $"))
diaslaborados=(30)
print(diaslaborados)
if edad > 55:
  print("Si recibe bono prepensional")
elif edad < 55:
  print("No recibe bono prepensional")
bono= sueldobasico* 0.05
total=sueldobasico + bono
print("El bono es = ${:,.0f} y el total a pagar es= ${:,.0f}".format(bono, total))
if estadocivil == "Casado":
  print("Aplica Paseo")
else:
    print("No aplica paseo decembrino")
    if sueldobasico>=1000000 <1500000:
      print("Aplica comisión del 2% sobre el sueldo")
    if sueldobasico>1500001<2000000:
      print("Aplica comisión del 5% sobre el sueldo")
      if sueldobasico>20000001:
        print("No aplica comisión")
if diaslaborados>20:
  print("Aplica bono de alimentación")
  if sueldobasico<1000000:
    print("Aplica bono de alimentación")
else: print("No aplica el bono de alimentación")
def validarestatura(estatura):
  if estatura > 165:
    print("Eres Alta")
  else:
    print("Eres baja")

resp = "si"
while resp == "si" or resp == "s":
  estatura = float(input("Digite su estatura: "))
  validarestatura(estatura)
  resp = input("¿Desea digitar otra estatura? ")
# Out:
# 52324966
# Diana
# Maria
# Valencia Escobar
# 3017982806
# Divorciada
# 2
# 170cm
# 30
# Si recibe bono prepensional
# El bono es = $50,000 y el total a pagar es= $1,050,000
# No aplica paseo decembrino
# Aplica comisión del 2% sobre el sueldo
# Aplica bono de alimentación
# Eres Alta
# Eres baja
